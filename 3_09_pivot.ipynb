# %% [markdown]
# <a href="https://colab.research.google.com/github/sokhan1/Introduction-to-data-analysts/blob/main/3_09_pivot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Long Form vs. Wide Form
#
# *   Long form represents data in more detail
# *   Flexible data manipulation, suitable for many forms of analysis
#
#
# *   Wide Form: Easy to see the overall structure of your data at a glance

# %%
import pandas as pd

long_form_data = {
    'Student': ['Alice', 'Alice', 'Alice', 'Bob', 'Bob', 'Bob'],
    'Subject': ['Math', 'Science', 'English', 'Math', 'Science', 'English'],
    'Score': [90, 85, 95, 75, 80, 78]
}

long_form_df = pd.DataFrame(long_form_data)

wide_form_data = {
    'Student':['Alice', 'Bob'],
    'Math': [90, 75],
    'Science': [85, 80],
    'English': [95, 78]
}

wide_form_df = pd.DataFrame(wide_form_data)

# %%
long_form_df
# Out:
#   Student  Subject  Score
# 0   Alice     Math     90
# 1   Alice  Science     85
# 2   Alice  English     95
# 3     Bob     Math     75
# 4     Bob  Science     80
# 5     Bob  English     78

# %%
wide_form_df
# Out:
#   Student  Math  Science  English
# 0   Alice    90       85       95
# 1     Bob    75       80       78

# %% [markdown]
# #df.melt()
#
#
#
# *   Unpivot(Melt) example:Convert from wide form to long form
# *   main parameters
#
#     *   id_vars: 데이터의 식별자 역할을 하는 열(들)의 이름을 나타냄. 이 열들은 그대로 유지됨
#     *   value_vars:'long form'으로 변환하고자 하는 열들의 이름
#     *   var_name:value_vars에 해당하는 열 이름들을 담을 새로운 열의 이름
#     *   value_name:value_vars에서의 값을 담을 새로운 열의 이름
#
#
#
#     *   unpivot_df =wide_form_df.melt(
#         id_vars='col_1'
#         , value_vars = ['col_2', col_3',...]
#         , var_name='col_name_1' # variable name
#         , value_name='col_name_2'
#     )

# %%
unpivot_df =wide_form_df.melt(
    id_vars='Student'
    , value_vars = ['Math', 'Science','English']
    , var_name='subject' # variable name
    , value_name='Score'
)
unpivot_df
# Out:
#   Student  subject  Score
# 0   Alice     Math     90
# 1     Bob     Math     75
# 2   Alice  Science     85
# 3     Bob  Science     80
# 4   Alice  English     95
# 5     Bob  English     78

# %% [markdown]
# #df.pivot_table
#
#
# *   Used to restructure the data frame
# *   summarize and group data by a specific key value.
#
#
#
# *   index:Columns used to group rows in a pivot table
# *   columns: columns used to group columns in a pivot table
# *   values: The column of data you want to analyze
# *   aggfunc: Aggregate functions, e.g.,np.sum,np.mean

# %% [markdown]
#     *   df.pivot_table(
#         index='col_1'
#         , columns='col_2'
#         , values='col_3'
#         ,aggfunc='min/max/...'
#         )

# %%
import pandas as pd

data = pd.DataFrame({
    'year': [2020, 2020, 2021, 2021, 2020, 2020, 2021, 2021],
    'region': ['East', 'West', 'East', 'West', 'East', 'West', 'East', 'West'],
    'category': ['Electronics', 'Electronics', 'Electronics','Electronics','Clothing', 'Clothing','Clothing','Clothing'],
    'sales':[100, 200, 300, 400, 150, 250, 350, 450],
    'profit':[20, 40, 60, 80, 30, 50, 70 ,90]
    })

# %%
data
# Out:
#    year region     category  sales  profit
# 0  2020   East  Electronics    100      20
# 1  2020   West  Electronics    200      40
# 2  2021   East  Electronics    300      60
# 3  2021   West  Electronics    400      80
# 4  2020   East     Clothing    150      30
# 5  2020   West     Clothing    250      50
# 6  2021   East     Clothing    350      70
# 7  2021   West     Clothing    450      90

# %%
data.pivot_table(
    index='region'
    , columns='year'
    , values='sales'
    ,aggfunc='sum'
    )
# Out:
# year    2020  2021
# region
# East     250   650
# West     450   850

# %%
data.pivot_table(
    index='region'
    , columns='category'
    , values='sales'
    ,aggfunc='mean'
    )
# Out:
# category  Clothing  Electronics
# region
# East           250          200
# West           350          300

# %% [markdown]
# #Exercise
#
#
# 1.   판다스의 melt 함수를 이용해 'iris'데이터셋을 'long form'으로 변환하시오
#     *   'variable' 열의이름은 'measure_type'으로, 'value' 열의 이름을 'measure_value'로 변경
#     *   iris_long으로 저장
#
# 2.   iris_long을 활용하여 species와 measure_type 별 평균을 구하시오

# %%
import pandas as pd
import seaborn as sns

iris = sns.load_dataset('iris', cache=False)

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_long =iris.melt(
    id_vars='species'
    , value_vars = ['sepal_length', 'sepal_width','petal_length','petal_width']
    , var_name='measure_type' # variable name
    , value_name='measure_value'
)
iris_long
# Out:
#        species  measure_type  measure_value
# 0       setosa  sepal_length            5.1
# 1       setosa  sepal_length            4.9
# 2       setosa  sepal_length            4.7
# 3       setosa  sepal_length            4.6
# 4       setosa  sepal_length            5.0
# ..         ...           ...            ...
# 595  virginica   petal_width            2.3
# 596  virginica   petal_width            1.9
# 597  virginica   petal_width            2.0
# 598  virginica   petal_width            2.3
# 599  virginica   petal_width            1.8
#
# [600 rows x 3 columns]

# %%
iris_long.pivot_table(
    index='species'
    , columns='measure_type'
    , values='measure_value'
    ,aggfunc='mean'
    )
# Out:
# measure_type  petal_length  petal_width  sepal_length  sepal_width
# species
# setosa               1.462        0.246         5.006        3.428
# versicolor           4.260        1.326         5.936        2.770
# virginica            5.552        2.026         6.588        2.974
