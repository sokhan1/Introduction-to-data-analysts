# %% [markdown]
# <a href="https://colab.research.google.com/github/sokhan1/Introduction-to-data-analysts/blob/main/3_02_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Dictionary

# %%
my_dict = {
    'key1': 'value1',
    'key2': 'value2',
    'key3': 'value3'
}

# %%
#Utilizing LIST for VALUE
dict1 ={
    'col1': [1,2,3,4],
    'col2': [10,20,30,40],
    'col3': [100,200,300,400],

}

dict1
# Out:
# {'col1': [1, 2, 3, 4], 'col2': [10, 20, 30, 40], 'col3': [100, 200, 300, 400]}

# %%
#Turn dictionary into dataframe
import pandas as pd
df=pd.DataFrame(dict1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    col1  col2  col3
# 0     1    10   100
# 1     2    20   200
# 2     3    30   300
# 3     4    40   400

# %% [markdown]
# #DataFrame
#
#
# *   head(): Shows the first 5 lines
# *   tail(): Shows the last 5 lines
# *   info(): column info, data type summary
# *   describe(): summarize numeric column statistics

# %%
# Importing data with seaborn
# https://github.com/mwaskom/seaborn-data
import seaborn as sns
df_iris = sns.load_dataset('iris')

# %%
df_iris.head(8)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa

# %%
df_iris.tail(8)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df_iris.info() #object is string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df_iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# #Exercise
#
#
# *   Import TITANIC data from SNS and find the top 25% AGEs

# %%
import seaborn as sns
df_titanic=sns.load_dataset('titanic')

df_titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
